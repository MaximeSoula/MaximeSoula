# %%
import numpy as np
import matplotlib.pyplot as plt
from math import *

# %%
import matplotlib.pyplot as plt
import numpy as np

T = 10
N = 10000
dt = T/N
t = np.linspace(1, T, N)
dW = np.random.standard_normal(size = N) 
W = np.cumsum(dW)*np.sqrt(dt) ### standard brownian motion ###
plt.plot(W)

j = arange(1, N)
sigma = 2+dt
X =

# %%
def fonction(t):
    return (2 + t)

t = np.linspace(1, 5, 1000)
plt.plot(t, fonction(t))
plt.grid()
plt.xlabel("t")
plt.ylabel("f(t)")
# Out:
# Text(0, 0.5, 'f(t)')

# %%
#intégrale :
a, b = 1, 5
n = 401
h = (b - a) / (n - 1)
print(h)

#ici h représente le pas.  n, représente le nombre de valeurs de t.
# Out:
# 0.01

# %%
t = np.linspace(a, b, n)
print(len(t), t[0], t[1], t[-1])
# Out:
# 401 1.0 1.01 5.0

# %%
integrale = 0
for i in range(n-1):
    integrale += ((t[i+1] - t[i])*(fonction(t[i+1]) + fonction(t[i]))/2)
print(integrale)
# Out:
# 1.2813614415216013

# %%
def Wiener():
    #global T, N, t : it says that we will use the precedent variables defined
    W=0
    Mylist =[]
    for t in range(0, 10000, 1): #range takes only integer
        if t = 0:
            W = 0
        else :
        W = W + np.random.standard_normal(size =1)
        Mylist.append(W) #On ajoute dans la liste le W au temps t.
    print(W)

Wiener()
# Out:
#   File "C:\Users\maxim\AppData\Local\Temp/ipykernel_25900/2491284126.py", line 6
#     if t = 0:
#          ^
# SyntaxError: invalid syntax
